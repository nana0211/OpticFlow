# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/lucerne/Developer/Python/opticalflow_magnitudes.csv', index_col=0)

# %%
df.describe()
# Out:
#        magnitude median  magnitude mean
# count       4300.000000     4300.000000
# mean           1.695865        4.519449
# std            1.771057        3.681625
# min            0.000000        0.000029
# 25%            0.000010        0.007800
# 50%            1.243569        5.976431
# 75%            3.061330        7.541061
# max            7.404381       12.672154

# %%
df
# Out:
#       magnitude median  magnitude mean
# 0         2.567252e+00        7.048216
# 1         8.757379e-06        0.005301
# 2         3.019101e+00        7.549615
# 3         2.327511e+00        7.235856
# 4         2.099155e+00        7.074337
# ...                ...             ...
# 4295      3.614098e-09        0.002233
# 4296      4.409189e-10        0.003038
# 4297      1.027204e-08        0.006018
# 4298      7.603110e-09        0.003123
# 4299      1.839675e-10        0.001455
#
# [4300 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['magnitude median', 'magnitude mean'], dtype='object')

# %%
sns.lineplot(data=df, x=df.index, y='magnitude median')

# plt.savefig('aaa.png')
# Out:
# <AxesSubplot:ylabel='magnitude median'>

# %%
sns.lineplot(data=df, x=df.index, y='magnitude mean')
# Out:
# <AxesSubplot:ylabel='magnitude mean'>
